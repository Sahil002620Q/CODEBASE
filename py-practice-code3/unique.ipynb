# %%
list = ['hii sahil'] 
list2 = ['how are you']
with open("raw_f.txt","r") as file:
    # file.write(f"{list}\n")
    # file.write(f"{list2}")
    # file.seek(0)
    read = file.read()
    print(repr(read),"\nvs")    #repr show raw representation
    print((read))
# Out:
# 'hii sahil\nhow are you'
# vs
# hii sahil
# how are you

# %%
import sqlite3

inject = ["sahil",7696274536]

# %%
try:
    with open("raw_f.txt","r") as file:
        raw = file.open()
        print(repr(raw))
except FileNotFoundError:
    print("file not found")
except:
    ("error")
print("done!")
# Out:
# done!

# %%
def read(file):
    try:
        with open(file,"r") as file:
            raw = file.read()
            print(raw)
    except FileNotFoundError:
        print("File not found, check whether file exist or not and try again")
    except:
        print("unexpected error, please try again later or check for errors")

read("raw_f.txt")
# Out:
# hii sahil
# how are you

# %%
try:   
    with open("raw_","r") as file:
        raw = file.read()
except FileNotFoundError:
    print("File not found, check whether file exist or not and try again")
except:
    print("unexpected error, please try again later or check for errors")
# Out:
# File not found, check whether file exist or not and try again

# %%
with open("raw_f.txt","r") as file:
    r = file.read()
    print(r)
# Out:
# hii sahil
# how are you
